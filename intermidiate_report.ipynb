# %% [markdown]
# ## Intermediate Report
#
# Author: Regina Blagotinšek
#
# Mentor: dr. Matjaž Depolli
#
# Supervisor: prof. dr. Sergio Cabello Justo
#
# Date: 5. 4. 2024
#
# ### 1 Introduction
#
# The title of my project is _Local prediction of weather parameters based on historical data_. The goal is to provide a short-term local forecast of weather parameters using historical data. The data is in the form of time series with 15 minute time intervals. My approach will use multivariate ARIMA statistical method to achieve accurate weather forecasting and asses the errors. The detailed task is written in the document _instructions.pdf_ in my GitHub repository. Further down the line the work on the project might take the tasks in a different direction, depending on the results I will be getting. First step of the project is to do a theoretical research of the ARIMA statistical method and some other similar methods that might be useful for the modelling. The modelling will be done with Python and the end result of the project will be a Jupiter notebook report with some visualisations and conclusions.
#
# ### 2 Theoretical background
#
# #### ARIMA
#
# ARIMA (Auto-Regressive Integrated Moving Average)  is a statistical analysis model used to forecast future points in time series data. It combines three main components: autoregression (AR), differencing (I), and moving average (MA).
#
# - **AR (Auto-Regressive):** This part predicts future values based on past values. It assumes a relationship between an observation and a number of lagged observations.
#
# - **I (Integrated):** To make the time series stationary, which means its statistical properties such as mean and variance are constant over time, differencing is used. This involves subtracting the previous observation from the current observation.
#
# - **MA (Moving Average):** This aspect models the error of the model as a combination of past errors in a moving average model.
#
# The ARIMA model is characterized by three parameters: _p_, _d_ and _q_. Paramether _p_ is the number of lag observations in the model (AR), _d_ is the degree of differencing (I), and _q_ is the size of the moving average window (MA).
#
# ARIMA models are widely used in economics, finance, and business for forecasting future trends from historical time series data. They are especially useful because they can handle data that shows non-stationary patterns and can incorporate the effects of past values and past errors into the model.
#
# ### 3 Data Visualisation
#
# Below there are plots of a section of the data for one of the weather stations to get an idea of what I have to work with. The parameters are ambient temperature, air pressure, wind speed and solar radiation intensity.
#
# #### Ambient temperature
#
# ![image-2.png](attachment:image-2.png)
#
# #### Air pressure
#
# ![image-3.png](attachment:image-3.png)
#
# #### Wind speed
#
# ![image-4.png](attachment:image-4.png)
#
# #### Solar radiation intensity
#
# ![image.png](attachment:image.png)
#
# ### 4 Plan of work
#
# 1. **Preparation Phase**:
#    - **Importing the data**
#    - **Python Script Review**
#
# 2. **Model Selection**:
#    - **Library Selection**: I will choose a Python library capable of ARIMA (or similar) statistical modeling. For example statsmodels and pmdarima.
#    - **Exploration and Learning**: I will first experiment with the selected library on a subset of the data to understand the capabilities and limitations of the models it can build.
#
# 3. **Development Phase**:
#    - **Model Development**
#    - **Forecast Function**
#    - **Accuracy Assessment Function**
#
# 4. **Testing Framework**:
#    - **Framework Creation**
#    - **Model Testing**
#
# 5. **Model Training and Evaluation**:
#    - **Full Dataset Training**
#    - **Data Splitting**
#    - **Optimization**
#
# 6. **Outcome and Refinement**:
#    - **Model Selection**
#    - **Final Testing**
#
# 7. **Documentation and Reporting**:
#    - **Documentation**
#    - **Report Preparation**
